# %%
import re
import requests
import time
import csv
from bs4 import BeautifulSoup
from requests.exceptions import RequestException


#Generate movies url list
def generate_movie_list_link(i):
    movie_list_url = "https://www.imdb.com/search/title/?title_type=tv_movie&release_date=2011-01-01,2019-09-22&sort=num_votes,desc&start="+str((i-1)*50+1)+"&ref_=adv_nxt"
    return  movie_list_url

#Get all the movies links, ratings, imdb_id, movie_year
def get_IMDB_Movie(url):
    URL = url
    try:
        response = requests.get(URL)
        if response.status_code == 200:
            html = response.text
            soup = BeautifulSoup(html,'lxml')
            movies = soup.select('.lister-item-content')
            l = [[0] * 3 for j in range(50)]
            i = 0
            for movie in movies:
                ratings_bar = movie.select_one('.ratings-bar')
                movie_rate = ratings_bar.select_one('div[name="ir"]')['data-value']      #Ratings
                header = movie.select_one('.lister-item-header')
                movie_link = header.select_one('a')['href']                     #Movie links
                id_pattern = re.compile(r'(?<=tt)\d+(?=/?)')
                movie_id = int(id_pattern.search(movie_link).group())           #imdb_id
                movie_name = header.select_one('a').string                      #movie_name
                s = header.select_one('.lister-item-year.text-muted.unbold').string                   #movie_year
                movie_year = s[1:5]

                #URL of user reviews on each movie
                movie_reviews_url = "https://www.imdb.com/title/"+str(movie_id)+"/reviews?ref_=tt_ov_rt"

                l[i] = [movie_id,movie_name,movie_rate]
                i += 1

                #print(i,movie_id,movie_name,movie_year,movie_rate,movie_reviews_url)
                #time.sleep(1)
            return l
        else:
            print("Error when request URL")
    except RequestException:
        print("Request Failed")
        return None

if __name__ == '__main__':
    i = 1
    with open('movie_info.csv', 'w', newline="",encoding='utf-8') as csvfile:
        csvwriter = csv.writer(csvfile, dialect=("excel"))
        csvwriter.writerow(["movieId", "movieName", "movieRate"])
        while(i <= 200):
            movie_list_url = generate_movie_list_link(i)
            print("Page" + str(i))
            l = get_IMDB_Movie(movie_list_url)
            j = 0
            while(j<50):
                 csvwriter.writerow(l[j])
                 j += 1
            i += 1
# Out:
# Page1
# Page2
# Page3
# Page4
# Page5
# Page6
# Page7
# Page8
# Page9
# Page10
# Page11
# Page12
# Page13
# Page14
# Page15
# Page16
# Page17
# Page18
# Page19
# Page20
# Page21
# Page22
# Page23
# Page24
# Page25
# Page26
# Page27
# Page28
# Page29
# Page30
# Page31
# Page32
# Page33
# Page34
# Page35
# Page36
# Page37
# Page38
# Page39
# Page40
# Page41
# Page42
# Page43
# Page44
# Page45
# Page46
# Page47
# Page48
# Page49
# Page50
# Page51
# Page52
# Page53
# Page54
# Page55
# Page56
# Page57
# Page58
# Page59
# Page60
# Page61
# Page62
# Page63
# Page64
# Page65
# Page66
# Page67
# Page68
# Page69
# Page70
# Page71
# Page72
# Page73
# Page74
# Page75
# Page76
# Page77
# Page78
# Page79
# Page80
# Page81
# Page82
# Page83
# Page84
# Page85
# Page86
# Page87
# Page88
# Page89
# Page90
# Page91
# Page92
# Page93
# Page94
# Page95
# Page96
# Page97
# Page98
# Page99
# Page100
# Page101
# Page102
# Page103
# Page104
# Page105
# Page106
# Page107
# Page108
# Page109
# Page110
# Page111
# Page112
# Page113
# Page114
# Page115
# Page116
# Page117
# Page118
# Page119
# Page120
# Page121
# Page122
# Page123
# Page124
# Page125
# Page126
# Page127
# Page128
# Page129
# Page130
# Page131
# Page132
# Page133
# Page134
# Page135
# Page136
# Page137
# Page138
# Page139
# Page140
# Page141
# Page142
# Page143
# Page144
# Page145
# Page146
# Page147
# Page148
# Page149
# Page150
# Page151
# Page152
# Page153
# Page154
# Page155
# Page156
# Page157
# Page158
# Page159
# Page160
# Page161
# Page162
# Page163
# Page164
# Page165
# Page166
# Page167
# Page168
# Page169
# Page170
# Page171
# Page172
# Page173
# Page174
# Page175
# Page176
# Page177
# Page178
# Page179
# Page180
# Page181
# Page182
# Page183
# Page184
# Page185
# Page186
# Page187
# Page188
# Page189
# Page190
# Page191
# Page192
# Page193
# Page194
# Page195
# Page196
# Page197
# Page198
# Page199
# Page200
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-b3955f169ce4> in <module>
#      57             movie_list_url = generate_movie_list_link(i)
#      58             print("Page" + str(i))
# ---> 59             l = get_IMDB_Movie(movie_list_url)
#      60             j = 0
#      61             while(j<50):
#
# <ipython-input-1-b3955f169ce4> in get_IMDB_Movie(url)
#      25             for movie in movies:
#      26                 ratings_bar = movie.select_one('.ratings-bar')
# ---> 27                 movie_rate = ratings_bar.select_one('div[name="ir"]')['data-value']      #Ratings
#      28                 header = movie.select_one('.lister-item-header')
#      29                 movie_link = header.select_one('a')['href']                     #Movie links
#
# TypeError: 'NoneType' object is not subscriptable

# %%
import re
import requests
import time
import csv
from selenium import webdriver
from bs4 import BeautifulSoup
from requests.exceptions import RequestException

def generate_movie_list_link(i):
    movie_list_url = "https://www.imdb.com/search/title/?title_type=tv_movie&release_date=2011-01-01,2019-09-22&sort=num_votes,desc&start="+str((i-1)*50+1)+"&ref_=adv_nxt"
    return  movie_list_url

def generate_movie_review_list_link(url):
    URL = url
    try:
        response = requests.get(URL)
        if response.status_code == 200:
            html = response.text
            soup = BeautifulSoup(html,'lxml')
            movies = soup.select('.lister-item-content')
            movie_reviews_url_list = [[0] * 2 for j in range(50)]
            i = 0
            for movie in movies:
                header = movie.select_one('.lister-item-header')
                movie_link = header.select_one('a')['href']                     #movie links
                id_pattern = re.compile(r'(?<=tt)\d+(?=/?)')
                movie_id = int(id_pattern.search(movie_link).group())           #imdb id
                movie_reviews_url = "https://www.imdb.com/title/tt"+str(movie_id)+"/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0"

                movie_reviews_url_list[i] = [movie_id,movie_reviews_url]
                i += 1
                #print(i,movie_id,movie_reviews_url)
                #time.sleep(1)
            return movie_reviews_url_list
        else:
            print("Error when request URL")
    except RequestException:
        print("Request Failed")
        return None

# %%
#Get all the reviews from non-spoiler on imdb movie review page
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager

def get_imdb_movie_review(url,movieId):
    NETWORK_STATUS = True  
    URL = url
    print(URL)
    try:
        response = requests.get(URL)
        if response.status_code == 200:
            original_html = response.text
            original_soup = BeautifulSoup(original_html,'lxml')
            driver = webdriver.Chrome(ChromeDriverManager().install())
            driver.get(URL)

            
            # Check if it needs to click load more button
            while(1):
                temp_response = driver.page_source
                temp_html = temp_response
                temp_soup = BeautifulSoup(temp_html,'lxml')
                load_more = temp_soup.select('.ipl-load-more__button')
                # Click load more button
                if(len(load_more) == 1):
                    button_load_more = driver.find_element_by_class_name('ipl-load-more__button')
                    button_is_or_not_visible = driver.find_element_by_class_name('ipl-load-more__button').is_displayed()
                    if(button_is_or_not_visible is True):       #Stop when the button is not visible
                        button_load_more.click()
                        time.sleep(1)
                    else:
                        break
                else:
                    break

            final_response = driver.page_source
            html = final_response
            soup = BeautifulSoup(html,'lxml')

            movie_id = movieId
            reviews = soup.select('.review-container')
            movie_reviews_list = [[0] * 6 for j in range(500)]

            i = 0
            for review in reviews:
                header = review.select_one('.display-name-date')
                user_link = header.select_one('a')['href']
                user_id_pattern = re.compile(r'(?<=ur)\d+(?=/?)')
                user_id = int(user_id_pattern.search(user_link).group())    #user id
                review_date = header.select_one('.review-date').string      #user review time
                review_title = review.find(class_="title").text   #user review title
                try:
                    rating = review.find(class_="point-scale").previous_sibling.text #user rating
                except:
                    rating = ""

                content = review.select_one('.content')
                user_review = content.select('.text.show-more__control')     #user review
                
                movie_reviews_list[i][0] = user_id
                movie_reviews_list[i][1] = review_date
                movie_reviews_list[i][2] = review_title
                movie_reviews_list[i][3] = user_review
                movie_reviews_list[i][4] = movie_id               
                movie_reviews_list[i][5] = rating

                i += 1
                #print(i,user_id,review_date,user_review,movie_id)
                time.sleep(0.1)

            driver.close()      #close the page
            return movie_reviews_list
        else:
            print("Error when request URL")
    except RequestException:
        print("Request Failed")
        return None
    except requests.exceptions.Timeout:
        NETWORK_STATUS = False  # Change the status when request timed out
        if NETWORK_STATUS == False:
            
            driver.close()  #close the page
            print('Request timed out. Repeat request')
            get_imdb_movie_review(URL, movieId)

if __name__ == '__main__':
    i = 0
    count = 0
    with open('movie_review_info.csv', 'w', newline="",encoding='utf-8') as csvfile:
        csvwriter = csv.writer(csvfile, dialect=("excel"))
        csvwriter.writerow(["userId", "reviewDate", "reviewTitle","userReview","movieId","Rating"])
        while (i <= 199):
             print("Page" + str(i+1) + " of movies")
             movie_list_url = generate_movie_list_link(i + 1)
             movie_review_url_list =  generate_movie_review_list_link(movie_list_url)
             j = 0

             while (j < 50):
                 print("Movie" + str(i * 50 + j + 1) + " reviews")
                 l = [[0] * 4 for j in range(500)]
                 l = get_imdb_movie_review(movie_review_url_list[j][1], movie_review_url_list[j][0])
                 k = 0
                 if(l is None):
                     j += 1
                     continue

                 while(l[k][0] != 0):
                     csvwriter.writerow(l[k])
                     k += 1
                     count += 1
                 j += 1
             i += 1

    print("Done. There are "+str(count)+" users' reviews in total")
# Out:
# Page1 of movies
# Movie1 reviews
# https://www.imdb.com/title/tt2724064/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2 reviews
# https://www.imdb.com/title/tt1684226/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie3 reviews
# https://www.imdb.com/title/tt1510938/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie4 reviews
# https://www.imdb.com/title/tt1278469/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie5 reviews
# https://www.imdb.com/title/tt1132623/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie6 reviews
# https://www.imdb.com/title/tt1848902/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie7 reviews
# https://www.imdb.com/title/tt1679235/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie8 reviews
# https://www.imdb.com/title/tt1933667/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie9 reviews
# https://www.imdb.com/title/tt3062074/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie10 reviews
# https://www.imdb.com/title/tt2279864/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie11 reviews
# https://www.imdb.com/title/tt1704292/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie12 reviews
# https://www.imdb.com/title/tt3895884/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie13 reviews
# https://www.imdb.com/title/tt1252380/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie14 reviews
# https://www.imdb.com/title/tt1742683/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie15 reviews
# https://www.imdb.com/title/tt1797469/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie16 reviews
# https://www.imdb.com/title/tt3440298/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie17 reviews
# https://www.imdb.com/title/tt1648204/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie18 reviews
# https://www.imdb.com/title/tt2287663/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie19 reviews
# https://www.imdb.com/title/tt1493842/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie20 reviews
# https://www.imdb.com/title/tt4943998/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie21 reviews
# https://www.imdb.com/title/tt3791216/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie22 reviews
# https://www.imdb.com/title/tt1930315/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie23 reviews
# https://www.imdb.com/title/tt1579247/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie24 reviews
# https://www.imdb.com/title/tt1646876/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie25 reviews
# https://www.imdb.com/title/tt3899796/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie26 reviews
# https://www.imdb.com/title/tt3318220/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie27 reviews
# https://www.imdb.com/title/tt2770480/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie28 reviews
# https://www.imdb.com/title/tt1835977/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie29 reviews
# https://www.imdb.com/title/tt2095605/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie30 reviews
# https://www.imdb.com/title/tt8425058/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie31 reviews
# https://www.imdb.com/title/tt1658851/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie32 reviews
# https://www.imdb.com/title/tt2325989/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie33 reviews
# https://www.imdb.com/title/tt3074694/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie34 reviews
# https://www.imdb.com/title/tt423455/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
# Error when request URL
# Movie35 reviews
# https://www.imdb.com/title/tt3145422/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie36 reviews
# https://www.imdb.com/title/tt5886510/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie37 reviews
# https://www.imdb.com/title/tt4366830/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie38 reviews
# https://www.imdb.com/title/tt5012394/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie39 reviews
# https://www.imdb.com/title/tt2008633/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie40 reviews
# https://www.imdb.com/title/tt4271918/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie41 reviews
# https://www.imdb.com/title/tt1825918/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie42 reviews
# https://www.imdb.com/title/tt2090440/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie43 reviews
# https://www.imdb.com/title/tt1595842/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie44 reviews
# https://www.imdb.com/title/tt2308733/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie45 reviews
# https://www.imdb.com/title/tt4831420/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie46 reviews
# https://www.imdb.com/title/tt1845866/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie47 reviews
# https://www.imdb.com/title/tt6868216/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie48 reviews
# https://www.imdb.com/title/tt4135218/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie49 reviews
# https://www.imdb.com/title/tt2132485/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie50 reviews
# https://www.imdb.com/title/tt1267299/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Page2 of movies
# Movie51 reviews
# https://www.imdb.com/title/tt1619880/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie52 reviews
# https://www.imdb.com/title/tt1625340/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie53 reviews
# https://www.imdb.com/title/tt5117876/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie54 reviews
# https://www.imdb.com/title/tt1745862/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie55 reviews
# https://www.imdb.com/title/tt4552118/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie56 reviews
# https://www.imdb.com/title/tt1083448/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie57 reviews
# https://www.imdb.com/title/tt2663812/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie58 reviews
# https://www.imdb.com/title/tt1697851/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie59 reviews
# https://www.imdb.com/title/tt1820723/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie60 reviews
# https://www.imdb.com/title/tt5017060/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie61 reviews
# https://www.imdb.com/title/tt1666642/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie62 reviews
# https://www.imdb.com/title/tt5262792/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie63 reviews
# https://www.imdb.com/title/tt2388986/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie64 reviews
# https://www.imdb.com/title/tt1587807/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie65 reviews
# https://www.imdb.com/title/tt7133092/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie66 reviews
# https://www.imdb.com/title/tt4434688/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie67 reviews
# https://www.imdb.com/title/tt2904608/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie68 reviews
# https://www.imdb.com/title/tt3831810/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie69 reviews
# https://www.imdb.com/title/tt1615091/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie70 reviews
# https://www.imdb.com/title/tt1709157/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie71 reviews
# https://www.imdb.com/title/tt3659786/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie72 reviews
# https://www.imdb.com/title/tt1614950/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie73 reviews
# https://www.imdb.com/title/tt6268052/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie74 reviews
# https://www.imdb.com/title/tt2448374/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie75 reviews
# https://www.imdb.com/title/tt1876547/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie76 reviews
# https://www.imdb.com/title/tt3118958/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie77 reviews
# https://www.imdb.com/title/tt10090796/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie78 reviews
# https://www.imdb.com/title/tt6298780/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie79 reviews
# https://www.imdb.com/title/tt1311076/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie80 reviews
# https://www.imdb.com/title/tt6543420/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie81 reviews
# https://www.imdb.com/title/tt1846442/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie82 reviews
# https://www.imdb.com/title/tt2569088/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie83 reviews
# https://www.imdb.com/title/tt4608402/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie84 reviews
# https://www.imdb.com/title/tt2180158/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie85 reviews
# https://www.imdb.com/title/tt5362352/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie86 reviews
# https://www.imdb.com/title/tt1828976/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie87 reviews
# https://www.imdb.com/title/tt3205394/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie88 reviews
# https://www.imdb.com/title/tt4262142/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie89 reviews
# https://www.imdb.com/title/tt1117646/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie90 reviews
# https://www.imdb.com/title/tt1499249/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie91 reviews
# https://www.imdb.com/title/tt1691338/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie92 reviews
# https://www.imdb.com/title/tt4163668/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie93 reviews
# https://www.imdb.com/title/tt3496892/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie94 reviews
# https://www.imdb.com/title/tt2375255/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie95 reviews
# https://www.imdb.com/title/tt1790621/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie96 reviews
# https://www.imdb.com/title/tt2421662/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie97 reviews
# https://www.imdb.com/title/tt1865368/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie98 reviews
# https://www.imdb.com/title/tt1651062/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie99 reviews
# https://www.imdb.com/title/tt1743360/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie100 reviews
# https://www.imdb.com/title/tt2011325/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Page3 of movies
# Movie101 reviews
# https://www.imdb.com/title/tt3704352/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie102 reviews
# https://www.imdb.com/title/tt1693872/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie103 reviews
# https://www.imdb.com/title/tt5456120/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie104 reviews
# https://www.imdb.com/title/tt2963232/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie105 reviews
# https://www.imdb.com/title/tt3544734/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie106 reviews
# https://www.imdb.com/title/tt6540078/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie107 reviews
# https://www.imdb.com/title/tt1618435/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie108 reviews
# https://www.imdb.com/title/tt1954299/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie109 reviews
# https://www.imdb.com/title/tt7344360/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie110 reviews
# https://www.imdb.com/title/tt2838678/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie111 reviews
# https://www.imdb.com/title/tt3822818/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie112 reviews
# https://www.imdb.com/title/tt2762970/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie113 reviews
# https://www.imdb.com/title/tt1623742/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie114 reviews
# https://www.imdb.com/title/tt3347518/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie115 reviews
# https://www.imdb.com/title/tt1699746/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie116 reviews
# https://www.imdb.com/title/tt2815030/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie117 reviews
# https://www.imdb.com/title/tt1807892/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie118 reviews
# https://www.imdb.com/title/tt4457038/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie119 reviews
# https://www.imdb.com/title/tt4573800/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie120 reviews
# https://www.imdb.com/title/tt2904626/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie121 reviews
# https://www.imdb.com/title/tt7074092/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie122 reviews
# https://www.imdb.com/title/tt5133572/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie123 reviews
# https://www.imdb.com/title/tt6739094/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie124 reviews
# https://www.imdb.com/title/tt1680138/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie125 reviews
# https://www.imdb.com/title/tt1886644/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie126 reviews
# https://www.imdb.com/title/tt3764966/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie127 reviews
# https://www.imdb.com/title/tt6326286/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie128 reviews
# https://www.imdb.com/title/tt2415112/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie129 reviews
# https://www.imdb.com/title/tt2284766/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie130 reviews
# https://www.imdb.com/title/tt5651050/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie131 reviews
# https://www.imdb.com/title/tt1673423/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie132 reviews
# https://www.imdb.com/title/tt1754799/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie133 reviews
# https://www.imdb.com/title/tt5676118/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie134 reviews
# https://www.imdb.com/title/tt1696192/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie135 reviews
# https://www.imdb.com/title/tt2377132/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie136 reviews
# https://www.imdb.com/title/tt3534842/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie137 reviews
# https://www.imdb.com/title/tt2395247/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie138 reviews
# https://www.imdb.com/title/tt5686132/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie139 reviews
# https://www.imdb.com/title/tt8031422/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie140 reviews
# https://www.imdb.com/title/tt1315216/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie141 reviews
# https://www.imdb.com/title/tt3131456/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie142 reviews
# https://www.imdb.com/title/tt2241676/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie143 reviews
# https://www.imdb.com/title/tt7126746/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie144 reviews
# https://www.imdb.com/title/tt8022928/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie145 reviews
# https://www.imdb.com/title/tt1831829/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie146 reviews
# https://www.imdb.com/title/tt1684927/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie147 reviews
# https://www.imdb.com/title/tt2165933/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie148 reviews
# https://www.imdb.com/title/tt2600742/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie149 reviews
# https://www.imdb.com/title/tt1792794/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie150 reviews
# https://www.imdb.com/title/tt2355762/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Page4 of movies
# Movie151 reviews
# https://www.imdb.com/title/tt3889642/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie152 reviews
# https://www.imdb.com/title/tt5664684/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie153 reviews
# https://www.imdb.com/title/tt5066870/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie154 reviews
# https://www.imdb.com/title/tt4247618/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie155 reviews
# https://www.imdb.com/title/tt5210380/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie156 reviews
# https://www.imdb.com/title/tt4060576/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie157 reviews
# https://www.imdb.com/title/tt3214240/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie158 reviews
# https://www.imdb.com/title/tt4180032/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie159 reviews
# https://www.imdb.com/title/tt6878820/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie160 reviews
# https://www.imdb.com/title/tt1545986/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie161 reviews
# https://www.imdb.com/title/tt4116030/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie162 reviews
# https://www.imdb.com/title/tt1451423/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie163 reviews
# https://www.imdb.com/title/tt2004262/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie164 reviews
# https://www.imdb.com/title/tt5033114/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie165 reviews
# https://www.imdb.com/title/tt4456850/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie166 reviews
# https://www.imdb.com/title/tt5302658/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie167 reviews
# https://www.imdb.com/title/tt4460176/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie168 reviews
# https://www.imdb.com/title/tt1710573/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie169 reviews
# https://www.imdb.com/title/tt3098874/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie170 reviews
# https://www.imdb.com/title/tt2117905/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie171 reviews
# https://www.imdb.com/title/tt1488598/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie172 reviews
# https://www.imdb.com/title/tt2039399/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie173 reviews
# https://www.imdb.com/title/tt6429934/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie174 reviews
# https://www.imdb.com/title/tt5572566/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie175 reviews
# https://www.imdb.com/title/tt3856042/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie176 reviews
# https://www.imdb.com/title/tt5739680/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie177 reviews
# https://www.imdb.com/title/tt2326087/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie178 reviews
# https://www.imdb.com/title/tt4184252/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie179 reviews
# https://www.imdb.com/title/tt5231268/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie180 reviews
# https://www.imdb.com/title/tt1679180/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie181 reviews
# https://www.imdb.com/title/tt3626180/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie182 reviews
# https://www.imdb.com/title/tt4767950/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie183 reviews
# https://www.imdb.com/title/tt1910605/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie184 reviews
# https://www.imdb.com/title/tt1747924/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie185 reviews
# https://www.imdb.com/title/tt1893218/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie186 reviews
# https://www.imdb.com/title/tt5133810/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie187 reviews
# https://www.imdb.com/title/tt4935200/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie188 reviews
# https://www.imdb.com/title/tt5076184/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie189 reviews
# https://www.imdb.com/title/tt5257726/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie190 reviews
# https://www.imdb.com/title/tt7473890/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie191 reviews
# ...
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2384 reviews
# https://www.imdb.com/title/tt2604640/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2385 reviews
# https://www.imdb.com/title/tt2562132/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2386 reviews
# https://www.imdb.com/title/tt2322822/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2387 reviews
# https://www.imdb.com/title/tt1734430/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2388 reviews
# https://www.imdb.com/title/tt1193126/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2389 reviews
# https://www.imdb.com/title/tt9815588/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2390 reviews
# https://www.imdb.com/title/tt8174646/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2391 reviews
# https://www.imdb.com/title/tt4643656/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2392 reviews
# https://www.imdb.com/title/tt4341518/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2393 reviews
# https://www.imdb.com/title/tt3437864/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2394 reviews
# https://www.imdb.com/title/tt3176298/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2395 reviews
# https://www.imdb.com/title/tt2460746/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2396 reviews
# https://www.imdb.com/title/tt2265427/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2397 reviews
# https://www.imdb.com/title/tt2136967/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2398 reviews
# https://www.imdb.com/title/tt2077909/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2399 reviews
# https://www.imdb.com/title/tt1900955/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2400 reviews
# https://www.imdb.com/title/tt1637729/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Page49 of movies
# Movie2401 reviews
# https://www.imdb.com/title/tt1595384/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2402 reviews
# https://www.imdb.com/title/tt9088954/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2403 reviews
# https://www.imdb.com/title/tt7834022/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2404 reviews
# https://www.imdb.com/title/tt7207076/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2405 reviews
# https://www.imdb.com/title/tt6339042/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2406 reviews
# https://www.imdb.com/title/tt5878262/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2407 reviews
# https://www.imdb.com/title/tt5130918/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2408 reviews
# https://www.imdb.com/title/tt3781666/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2409 reviews
# https://www.imdb.com/title/tt2575380/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2410 reviews
# https://www.imdb.com/title/tt2274760/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2411 reviews
# https://www.imdb.com/title/tt1855255/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2412 reviews
# https://www.imdb.com/title/tt1535080/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2413 reviews
# https://www.imdb.com/title/tt5941796/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2414 reviews
# https://www.imdb.com/title/tt5790504/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2415 reviews
# https://www.imdb.com/title/tt5577452/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2416 reviews
# https://www.imdb.com/title/tt4054760/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2417 reviews
# https://www.imdb.com/title/tt3327140/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2418 reviews
# https://www.imdb.com/title/tt2986442/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2419 reviews
# https://www.imdb.com/title/tt1711534/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2420 reviews
# https://www.imdb.com/title/tt1590010/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2421 reviews
# https://www.imdb.com/title/tt1558731/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2422 reviews
# https://www.imdb.com/title/tt10103960/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2423 reviews
# https://www.imdb.com/title/tt9569212/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2424 reviews
# https://www.imdb.com/title/tt8985014/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2425 reviews
# https://www.imdb.com/title/tt7775998/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2426 reviews
# https://www.imdb.com/title/tt6728618/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2427 reviews
# https://www.imdb.com/title/tt4160870/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2428 reviews
# https://www.imdb.com/title/tt3349356/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2429 reviews
# https://www.imdb.com/title/tt3215004/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2430 reviews
# https://www.imdb.com/title/tt1911663/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2431 reviews
# https://www.imdb.com/title/tt5459774/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2432 reviews
# https://www.imdb.com/title/tt5172570/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2433 reviews
# https://www.imdb.com/title/tt2605312/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2434 reviews
# https://www.imdb.com/title/tt2266608/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2435 reviews
# https://www.imdb.com/title/tt2211542/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2436 reviews
# https://www.imdb.com/title/tt1988184/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# Movie2437 reviews
# https://www.imdb.com/title/tt1849899/reviews?spoiler=hide&sort=helpfulnessScore&dir=desc&ratingFilter=0
#
# Checking for mac64 chromedriver:77.0.3865.40 in cache
# Driver found in /Users/Zoe/.wdm/chromedriver/77.0.3865.40/mac64/chromedriver
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# <ipython-input-6-d718c423802b> in <module>
#      99                  print("Movie" + str(i * 50 + j + 1) + " reviews")
#     100                  l = [[0] * 4 for j in range(500)]
# --> 101                  l = get_imdb_movie_review(movie_review_url_list[j][1], movie_review_url_list[j][0])
#     102                  k = 0
#     103                  if(l is None):
#
# <ipython-input-6-d718c423802b> in get_imdb_movie_review(url, movieId)
#      18             # Check if it needs to click load more button
#      19             while(1):
# ---> 20                 temp_response = driver.page_source
#      21                 temp_html = temp_response
#      22                 temp_soup = BeautifulSoup(temp_html,'lxml')
#
# //anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in page_source(self)
#     677             driver.page_source
#     678         """
# --> 679         return self.execute(Command.GET_PAGE_SOURCE)['value']
#     680
#     681     def close(self):
#
# //anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# //anaconda3/lib/python3.7/site-packages/selenium/webdriver/remote/errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoSuchWindowException: Message: no such window: window was already closed
#   (Session info: chrome=77.0.3865.90)

# %%
#!/usr/bin/env python

# import the needed libraries
import requests
from bs4 import BeautifulSoup
import pandas as pd
from tqdm import tqdm
import time

headers = {
    'headers': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_6) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/57.0.2987.133 Safari/537.36'}

def movies_data():
    'This return a dataframe for the top movies on www.imdb.com'
    base_url = 'https://www.imdb.com'
    url = base_url + '/chart/top'
    response = requests.get(url,headers= headers)
    soup = BeautifulSoup(response.text,'lxml')

    # set the data
    df = pd.read_html(url,header=0)[0]
    # extarct the rank
    df['rank'] =  df['Rank & Title'].apply(lambda x: x.split(' ')[0].replace('.',''))
    # extract the title
    df['title'] = df['Rank & Title'].apply(lambda x: ' '.join(x.split(' ')[2:-2]))
    # extarct the year
    df['year'] = df['Rank & Title'].apply(lambda x: x.split(' ')[-1].replace('(','').replace(')',''))
    #rename the redundant columns
    df.rename(columns={'IMDb Rating':'imdb_rate'}, inplace=True)
    # drop the unnamed and other columns
    col_to_drop = ['Unnamed: 0','Your Rating','Unnamed: 4', 'Rank & Title' ]
    df.drop(columns=col_to_drop, axis=1 , inplace=True)
    # adjust the rate type to float
    df.imdb_rate = df.imdb_rate.astype('float')
    # re arrange the columns
    cols = df.columns.tolist()
    cols  = cols[1:]+cols[:1]
    df = df[cols]
    # extract the table
    tb = soup.find('table')
    l = [tag.get('href') for tag in tb.find_all('a')]
    # clean as l is dupliacted
    href = [base_url+k for i, k in enumerate(l) if i%2 == 0]
    # collect the href links
    df['href'] = href
    return df

def movie_parser(movie_url):
    r = requests.get(movie_url,headers=headers)
    soup = BeautifulSoup( r.text, 'lxml')
    # get cast
    cast = ','.join([i.find('a').find('img').get('alt') for i in soup.findAll('td',{'class':"primary_photo"})])
    # get the movie summary
    summary = soup.find('div',{'class':"summary_text"}).text.strip()
    record = {'summary': summary, 'cast': cast}
    return record

if __name__ == '__main__':
    df = movies_data()
    print('Start scraping...')
    movies = [movie_parser(l) for l in tqdm(df.href)]
    s,c  = [i['summary'] for i in movies],[i['cast'] for i in movies]
    df['summary'] , df['cast'] = s ,c
    df.to_csv('top_movies_imdb.csv', encoding ='utf-8-sig' , index= False)
    print('data is saved!')

# %%
'''
Importing The Necessary Packages
'''
import json
import re
import requests
import warnings
import numpy as np
import pandas as pd
import mysql.connector
import urllib.request
from scipy import stats
import seaborn as sns
from bs4 import BeautifulSoup
from currency_converter import CurrencyConverter
from matplotlib import pyplot as plt
import nltk   
import unicodedata
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA 
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn import metrics as sm
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
warnings.filterwarnings('ignore')
sns.set(style="darkgrid", color_codes=True)

#########################################################################################################################
# Defining Functions
#########################################################################################################################
class ImdbMovies:
    model=''
    vectorizer=''
    mydb=''
    '''Loading constructor, so when instance is instantiate it will load our model and as well 
        as it will create a connection with the database'''
    def __init__(self,**kwargs):
        self.firstname=kwargs.get('firstname','Firstname Not Provided')
        self.lastname=kwargs.get('lastname','LastName Not Provided')
        self.mydb=self.DatabaseConnection('root','Sagar$256','imdbmovies')
        print("\nPlease wait {}, while we're running the model.....".format(self.firstname))
        self.model,self.vectorizer=self.UserReview_SentimentAnalyzer()
        print('''Done!!, you're good to go''')
        print("#########################################################################################################################")
        print("Welcome! {} {} to our movie search and data analysis program:\n".format(self.firstname.capitalize(),self.lastname.capitalize()))
        print("#########################################################################################################################")
     
    '''This is just to provide user freindly string when object is print'''             
    def __str__(self):
        return '''What's going on {} {}, enjoy your movie buddy'''.format(self.firstname.capitalize(),self.lastname.capitalize())
    
    '''Using Vader lexicon function to get the polarity'''
    def sentiment_lexicon(self,review, threshold=0.1):       
        sid = SIA()
        ss = sid.polarity_scores(review) 
        agg_score = ss['compound'] 
        if agg_score >= threshold:
            final_sentiment = 'Positive' 
        else:
            final_sentiment = 'Negative'
        return final_sentiment
    
    '''Sentiment analysis based on user review submited'''     
    def UserReview_SentimentAnalyzer(self):
        self.df=pd.read_sql("select imdbid,User_Review,Polarity from movies;",self.mydb)
        # User_Review
        self.data = self.df['User_Review']
        self.data=pd.Series.to_string(self.data)    ## converted to string from pandas.Series
        # for removing accented characters
        self.normal = unicodedata.normalize('NFKD', self.data).encode('ASCII', 'ignore')
        # sentiment_vader_lexicon:
        self.list_senti=[]
        for i in self.df['User_Review']:
            self.list_senti.append(self.sentiment_lexicon(i))
        self.list_senti
        #creating new column as sentiment which will have 0/1 values
        self.df['polarity']=self.list_senti
        # assigning
        self.features=self.df.loc[:,'User_Review']
        self.senti=self.df.loc[:,'polarity']
        # Using TFIDF vectorizer
        self.vectorizer = TfidfVectorizer(min_df= 3, stop_words="english", sublinear_tf=True, norm='l2', ngram_range=(1, 2))
        self.final_features = self.vectorizer.fit_transform(self.features).toarray()
        self.features_train,self.features_test,self.senti_train,self.senti_test=train_test_split(self.final_features,self.senti,test_size=0.2,random_state=23) 
        # SVC model to get acc & class table
        self.lsvm = LinearSVC()
        self.l = self.lsvm.fit(self.features_train,self.senti_train)
        return self.l,self.vectorizer
    
    '''Predictor function that will help to analyse user review and provide the polarity'''
    def Predict_Sentiment(self,model,vectorizer,User_Review):
    #    l=UserReview_SentimentAnalyzer()
        self.y = self.vectorizer.transform([self.User_Review]).toarray()
        self.z=model.predict(self.y)
        return self.z

    '''Displaying intial menu where user can select an option either to search the movie or analyse the movie '''
    def displayMenu(self):
        print("\nMenu:\n[S]earch Movie,[A]nalyze the data,[Q]uit:\n")
        print("---------------------------------------------------------------------------")
        Choice=''
        flag=0
        options={'s':'search','a':'analyse','q':'quit'}
        try:            
            Choice=input("Please enter your option below:\n").lower()           
            if Choice=='':
                flag=1  
                return Choice,flag
            elif Choice not in options.keys():
                flag=2
                return Choice,flag
            else:
                return Choice,flag
        except ValueError:
            print("\nInvalid input...please enter S,A,Q from choices provided:\n")
            self.displayMenu()
           
    '''Budget and Review need to be extracted from IMDB website '''
    def Extract_Budget_UserReview(self,imdbID):
        c = CurrencyConverter()
        CurrencyDict = {'$': 'USD', '£': 'GBP', '¥': 'JPY', '€': 'EUR', '₹': 'INR'}
        url = 'http://www.imdb.com/title/{}/?ref_=fn_al_nm_1a'.format(imdbID)
        data = requests.get(url)
        soup = BeautifulSoup(data.text, 'html.parser')
        Budget = 0
        userReview = ""
        
        #Extracting the user Review of the movie
        movie = soup.findAll('div', {'class': 'user-comments'})
        for res in movie:
            userReview = res.span.strong.text
            if userReview is None:
                userReview='N/A'
            
        #Extracting the Budget of the movie
        for h4 in soup.find_all('h4'):
            if "Budget:" in h4:
                Budget = h4.next_sibling
                match = re.search(r'([\D]+)([\d,]+)', Budget)
                output = (match.group(1).replace('\xa0', ''),
                          match.group(2).replace(',', ''))
                if len(output[0]) == 1:
                    Budget = round(
                        (c.convert(output[1], CurrencyDict[output[0]], 'USD')/1000000), 2)
                elif len(output[0]) == 3 and output[0] == 'XAF':
                    Budget = round((float(output[1])*0.00174637)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'FRF':
                    Budget = round((float(output[1])*0.17)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'IRR':
                    Budget = round((float(output[1])*0.0000237954)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'PKR':
                    Budget = round((float(output[1])*0.007225614)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'NPR':
                    Budget = round((float(output[1])*87.0521)/1000000, 2)
                elif len(output[0]) == 3 and output[0] != 'FRF':
                    Budget = round(
                        c.convert(output[1], output[0], 'USD')/1000000, 2)
        return Budget,userReview
    
    '''Extracting movie details from API'''
    def getMovieData(self,Movietitle):
        try:
            url = "http://www.omdbapi.com/?t={}&apikey=5ddb11dd".format(Movietitle)
            print("Retrieving the data of \"{}\" now…".format(Movietitle))
            api_request = requests.get(url)
            source = json.loads(api_request.content)
        except requests.RequestException as e:
            print(f"ERROR: {e.reason}")
        return source
    
    '''Establishing the database connection'''
    def DatabaseConnection(self,user, passwd, database):
        mydb=''
        try:
            mydb = mysql.connector.connect(host='localhost',
                                           user=user,
                                           passwd=passwd,
                                           db=database)
        except:
            print("""The login credentials you entered are not valid for
                the database you indicated.  Please check your login details and try
                again.""")        
        return mydb
    
    '''This function will sepearte each word from genre and stack it in long format'''
    def explode(self,df, lst_cols, fill_value=''):
        # make sure `lst_cols` is a list
        if lst_cols and not isinstance(lst_cols, list):
            lst_cols = [lst_cols]
        # all columns except `lst_cols`
        idx_cols = df.columns.difference(lst_cols)
    
        # calculate lengths of lists
        lens = df[lst_cols[0]].str.len()
    
        if (lens > 0).all():
            # ALL lists in cells aren't empty
            return pd.DataFrame({
                col: np.repeat(df[col].values, lens)
                for col in idx_cols
            }).assign(**{col: np.concatenate(df[col].values) for col in lst_cols}) \
              .loc[:, df.columns]
        else:
            # at least one list in cells is empty
            return pd.DataFrame({
                col: np.repeat(df[col].values, lens)
                for col in idx_cols
            }).assign(**{col: np.concatenate(df[col].values) for col in lst_cols}) \
              .append(df.loc[lens == 0, idx_cols]).fillna(fill_value) \
              .loc[:, df.columns]
    
    '''This Function will put the data extracted from API and from webscraping into movie database '''    
    def DataIntoDatabase(self,MovieData, mydb, mycursor):
        self.budget,self.User_Review = self.Extract_Budget_UserReview(MovieData['imdbID'])
        self.pred=self.Predict_Sentiment(self.model,self.vectorizer,self.User_Review)
        self.polarity=''.join(self.pred)
        if MovieData['Metascore'] == 'N/A':
           metascore = 0
        else:
           metascore = (float((MovieData['Metascore']))/10)
                    
        if MovieData['imdbRating']=='N/A':
           imdb_rating=0
        else:
           imdb_rating = float(MovieData['imdbRating'])
    
        if MovieData['Released']=='N/A':
           release_year=0
        else:
           release_year=int(MovieData['Released'].split(' ')[2])
            
        if MovieData['Poster']=="N/A":
           image_url='Image Not Available'
        else:
           image_url=MovieData['Poster']
            
        sql = """INSERT INTO movies(IMDBID, Title, Genre, Year, URL, Audience_Rating, Critic_Rating, Budget_In_Millions, User_Review,Polarity) 
                    VALUES (%s, %s,%s, %s,%s,%s,%s,%s,%s,%s)
                    ON DUPLICATE KEY UPDATE 
                    Audience_Rating=values(Audience_Rating),
                    Critic_Rating=values(Critic_Rating),
                    Budget_In_Millions=values(Budget_In_Millions),
                    User_Review=values(User_Review),
                    Polarity=values(Polarity);"""
    
        val=[(MovieData['imdbID'],MovieData['Title'],
            MovieData['Genre'],release_year,image_url,
            imdb_rating,metascore,self.budget,self.User_Review,self.polarity)] 
        mycursor.executemany(sql, val)
        mydb.commit()
 
    
    '''This function will fetch the data from database from the title provided by the user'''   
    def getDataFromDatabase(self,UserInputTitle):       
        mydb=self.mydb
        self.mycursor=mydb.cursor()  
        self.mycursor.execute("""select title,genre,year,audience_rating,critic_rating,polarity 
                         from movies where title like %s limit 1""",("%" + self.UserInputTitle + "%",))
        self.myresult = self.mycursor.fetchall()
        return self.myresult
    
    '''
    This is use to display info about the movie title provided by the user, 
    at the same time if the movie title doesn't exist the it will make an entry into the database 
    and then it will fetch the data from database to display info. 
    '''    
    def DisplayMovieInfo(self,UserInputTitle):   
        mydb=self.mydb
        mycursor=mydb.cursor()
        try:
            myresult=self.getDataFromDatabase(self.UserInputTitle)
            if not myresult:
                MovieData=self.getMovieData(self.UserInputTitle)
                if MovieData['Response']=='False':
                  print("Sorry!!! The Movie Doesn't Exist.....:(")
                else:
                    self.DataIntoDatabase(MovieData,mydb,mycursor)           
                    myresult=self.getDataFromDatabase(self.UserInputTitle)
                    if myresult[0][5]=='Positive':
                        res="Good Choice! & you can enjoy this with your buddy. :)"
                    else:
                        res="Well, you've decide so enjoy this with your popcorn. :)."
                print('*********************************************************')
                print("Title: {}".format(myresult[0][0]))
                print("Genre: {}".format(myresult[0][1]))
                print("Year: {}".format(myresult[0][2]))
                print("Audience Rating: {}".format(myresult[0][3]))
                print("Critic Rating: {}".format(myresult[0][4]))
                print("What's My Sugesstion: {}".format(res))
                print('*********************************************************')
            else:
                if myresult[0][5]=='Positive':
                    res="Your can enjoy this with your buddy!"
                else:
                    res="Well you've decide so enjoy with your popcorn."
                print('*********************************************************')
                print("Title: {}".format(myresult[0][0]))
                print("Genre: {}".format(myresult[0][1]))
                print("Year: {}".format(myresult[0][2]))
                print("Audience Rating: {}".format(myresult[0][3]))
                print("Critic Rating: {}".format(myresult[0][4]))
                print("What's My Sugesstion: {}".format(res))
                print('*********************************************************')
        except:
            print('''Sorry its doesnt exist...please try once again''')

    
    '''This Function will fetch the data by year'''
    def getDataByYear(self,FirstRange,SecondRange):       
        self.movieData=pd.read_sql("""select title,genre,year,audience_rating,critic_rating,budget_in_millions 
                                    from movies 
                                    where url!='N/A' and 
                                    genre!='N/A'and 
                                    year!=0 and 
                                    Audience_rating!=0 and 
                                    critic_rating!=0 and 
                                    budget_in_millions!=0 and 
                                    user_review <> ''and polarity <> '' and Year BETWEEN {} and {};""".format(FirstRange,SecondRange),self.mydb)
        return self.movieData

    '''Getting an input title from the user'''    
    def getChoiceMovie(self):    
        try:
            self.UserInputTitle=input("Please enter the title of the movie:\n")
            if self.UserInputTitle=='':
                print("No Input Provided.")
            else:
                self.DisplayMovieInfo(self.UserInputTitle)
        except ValueError:
            print("\nSome error occured.....please check the input provided")
    
    '''This fucntion will fetch the data from the database & process it while formatting the data in long format'''    
    def DataAnalysis(self):
        self.movieData=''
        self.year=pd.read_sql('''select max(year) as Max_Year, min(year) as Min_Year 
                             from movies where url!='N/A' and 
                             genre!='N/A'and year!=0 and 
                             Audience_rating!=0 and 
                             critic_rating!=0 and 
                             budget_in_millions!=0 and 
                             user_review <> '' and 
                             Polarity <>'' ''',self.mydb)
        
        print('***********************************************************************************************')
        print("Data is avialable from {} to {}.\nEnter the range so as to bring you the analysis".format(self.year.Min_Year[0],self.year.Max_Year[0]))
        print('***********************************************************************************************')
        try:
            self.FirstRange=input("Please Enter The Range 1:\n")
            self.SecondRange=input("Please Enter The Range 2:\n")
            if self.FirstRange=='' or self.SecondRange=='':
                print("No input was provided.\n")
                self.DataAnalysis()
            elif self.FirstRange > self.SecondRange:
                print('\nProvided range is invalid...since the first range cannot be greater than the second.\n')
                self.DataAnalysis()
            elif len(self.FirstRange)!=4 or len(self.SecondRange)!=4:
                print("Provided range is invalid...\n")
                self.DataAnalysis()
            else:
                self.movieData=self.getDataByYear(int(self.FirstRange),int(self.SecondRange))
                self.movieData.genre = self.movieData.genre.str.split(',')
                self.movieData = self.explode(self.movieData,['genre']) 
                self.movieData.genre=self.movieData.genre.str.strip(' ')
                self.movieData.genre=self.movieData.genre.astype('category')
                self.movieData.audience_rating=self.movieData.audience_rating*10
                self.movieData.critic_rating=self.movieData.critic_rating*10
    
        except ValueError:
            print("Please provide correct input...since the entered value is not a number.\n")
            self.DataAnalysis()
        return self.movieData
    
    def OptionChoice(self):
        print("""Please Choose option below:
        1. Display Top 10 Rated Movies
        2. Display Top 10 High Budget Movies
        3. Display Critic Vs Audience Rating
        4. Distribution of Critic or Audience Rating
        5. Display Stack Distribution of Budget
        6. Display Boxplot
        7. Display Barplot\n
            """)
    
    def OptionChoiceDist(self):
        self.optionDist={1:'Critic Rating Distribution',2:'Audience Rating Distribution'}
        print("""Please Enter:\n[1] Critic Rating Distribution\n[2] Audience Rating Distribution\n""")
        try:
            self.Dist=int(input(">"))
            if self.Dist not in self.optionDist.keys():
                print("Sorry please enter your choice from the option below\n")
                self.OptionChoiceDist()
            elif self.Dist==1:
                self.DisplayHistogram(self.movieData,'critic rating')
            elif self.Dist==2:
                self.DisplayHistogram(self.movieData,'audience rating')                              
        except ValueError:
            print("Invalid input provided.")
            self.OptionChoiceDist()
            
    def OptionChoiceBox(self):
        self.optionbox={1:'Critic Rating Boxplot',2:'Audience Rating Boxplot'}
        print("""Please Enter:\n[1] Display boxplot for critic rating by genre\n[2] Display boxplot for audience rating by genre\n""")
        try:
            self.box=int(input(">"))
            if self.box not in self.optionbox.keys():
                print("Sorry please enter your choice from the option below\n")
                self.OptionChoiceBox()
            elif self.box==1:
                self.DisplayBoxplot(self.movieData,'genre','critic rating')
            elif self.box==2:
                self.DisplayBoxplot(self.movieData,'genre','audience rating')
        except ValueError:
            print("Invalid input provided.")
            self.OptionChoiceBox()
    
    def OptionChoiceBar(self):
        self.optionbar={1:'Genre bar plot',2:'Year bar plot'}
        print("""Please Enter:\n[1] Display barplot to display Data by Genre\n[2] Display barplot to display Data by year:\n""")
        try:
            self.bar=int(input(">"))
            if self.bar not in self.optionbar.keys():
                print("Sorry please enter your choice from the option below\n")
                self.OptionChoiceBar()
            elif self.bar==1:
                self.catPlot(self.movieData,'genre')
            elif self.bar==2:
                self.catPlot(self.movieData,'year')
        except ValueError:
            print("Invalid input provided.")
            self.OptionChoiceBar()
       
    def DisplayCricticAudienceRating(self,movieData):
        #Joint Plot Critic Rating Vs Audience Rating
        sns.set(style='whitegrid')
        sns.jointplot(data=self.movieData,x='critic_rating',y='audience_rating')
        j = sns.JointGrid(data=self.movieData,x='critic_rating',y='audience_rating')
        j = j.plot_joint(plt.scatter,color="g", s=40, edgecolor="black")
        j = j.plot_marginals(sns.distplot, kde=False,)
        j = j.annotate(stats.pearsonr,loc="upper left")
        j.set_axis_labels('Critic Ratings','Audience Rating')
        plt.show()
    
    # Histogram
    def DisplayHistogram(self,movieData,column):
        column=column.title()
        LabelDictCol = {'Critic Rating':'critic_rating','Audience Rating':'audience_rating','Budget In Millions':'budget_in_millions'}        
        sns.set(style = 'whitegrid')
        fig,ax=plt.subplots()
        fig.set_size_inches(11.7,8.27)
        plt.hist(movieData[LabelDictCol[column]],bins=15,color='black')
        plt.title("{} Distribution".format(column),fontsize=20)
        plt.ylabel("Frequency",fontsize=15)
        plt.xlabel("{} (%)".format(column),fontsize=15)
        plt.show()
    
    # Stack distribution
    def DisplayStackedHistogram(self,movie):
        list1=[]
        GenreLabels=[]
        for gen in movie.genre.cat.categories:
            list1.append(movie[movie.genre==gen].budget_in_millions)
            GenreLabels.append(gen)
            sns.set(style='whitegrid')        
        fig,ax=plt.subplots()
        fig.set_size_inches(11.7,8.27)
        plt.hist(list1,bins=30,stacked=True,rwidth=1,label=GenreLabels)
        plt.title("Movie Budget Distribution",fontsize=20)
        plt.ylabel("Number of Movies",fontsize=15)
        plt.xlabel("Budget$$$",fontsize=15)
        plt.legend(frameon=True,fancybox=True,prop={'size':10},framealpha=1)
        plt.show()
    
    
    # how critic rating is dtributted accross different genre
    def DisplayBoxplot(self,data,column1,column2): 
        column1=column1.title()
        column2=column2.title()
        LabelDictCol = {'Critic Rating':'critic_rating','Audience Rating':'audience_rating','Budget In Millions':'budget_in_millions','Genre':'genre','Year':'year'}        
        fig,ax=plt.subplots() 
        fig.set_size_inches(11.7,8.27)
        sns.boxplot(data=data,x=LabelDictCol[column1],y=LabelDictCol[column2],palette='vlag',whis="range")
        ax.yaxis.grid(True)
        ax.xaxis.grid(True)
        plt.title('{} Vs {} Boxplot'.format(column1,column2),fontsize=20)
        plt.xlabel('{}'.format(column1),fontsize=15)
        plt.ylabel('{}'.format(column2),fontsize=15)
        plt.xticks(rotation=30)
        sns.despine(trim=True, left=True)
        plt.show()    

    '''Function is use to display barplot for number of movie by genre or year'''
    def catPlot(self,data,column):
        column=column.title()
        LabelDictCol = {'Critic Rating':'critic_rating','Audience Rating':'audience_rating','Budget In Millions':'budget_in_millions','Genre':'genre','Year':'year'}      
        sns.catplot(y=LabelDictCol[column], kind="count", palette="ch:.25", data=data)
        plt.title('Barplot For {}'.format(column.capitalize()),fontsize=20)
        plt.ylabel('{}'.format(column.capitalize()),fontsize=15)
        plt.xlabel('')
        plt.show()
    
    '''Display top 10 movie w.r.t genre or year'''
    def getTop10(self,data):
        p=sns.factorplot(aspect=1.5,y='title',x='audience_rating',data=data.sort_values(['audience_rating','critic_rating'],ascending=False).drop(['genre'],axis=1).drop_duplicates().head(10),palette="ch:.25",kind='bar')
        p.set(xlim=(10,100))
        sns.set_style("ticks",{"xtick.major.size":8,"ytick.major.size":8})
        plt.title('Top 10 Rated Movies',fontsize=20)
        plt.ylabel('Title',fontsize=15)
        plt.xlabel('Audience Rating',fontsize=15)
        sns.despine(trim=True,left=True)
        plt.show()
    
    '''Function will display top 10 movie w.r.t budget'''
    def getTop10HighBudgetMovie(self,data):
        sns.factorplot(aspect=1.5,y='title',x='budget_in_millions',data=data.sort_values(['budget_in_millions'],ascending=False).drop(['genre'],axis=1).drop_duplicates().head(10),palette="ch:.25",kind='bar')
        sns.set_style("ticks",{"xtick.major.size":8,"ytick.major.size":8})
        plt.title('Top 10 High Budget Movies',fontsize=20)
        plt.ylabel('Title',fontsize=15)
        plt.xlabel('Budget In Millions',fontsize=15)
        sns.despine(trim=True,left=True)
        plt.show()            
    
    
    '''This is function will be call after the object is created and its link with mulitple functions from above'''    
    def DisplayTheDetails(self):
        self.options={'s':'search','a':'analyse','q':'quit'}
        while True:            
            Choice,flag = self.displayMenu()
            if flag==1 and Choice=='':
                print("Please select the option from the menu:\n")
                break
                self.displayMenu()
            elif flag==2 and Choice not in self.options.keys():
                print("Please select the option from the menu:\n")
                break
                self.displayMenu()
            elif flag==0 and Choice in self.options.keys():
                if Choice == 's':
                    self.getChoiceMovie()
                    break
                elif Choice == 'a':
                    self.optionAnalyze={1:'Display Top 10 Rated Movies',2:'Display Top 10 High Budget Movies',3: 'Display Critic Vs Audience',
                     4:'Distribution of Critic Vs Audience',5:'Display Stack Distribution of Budget',6:'Display Boxplot',7:'Display Barplot',
                     8:'Display Dashboard'}  
                    self.movieData=self.DataAnalysis()
                    try:
                        self.OptionChoice()
                        choice=int(input("Please enter the option below:\n"))
                        if choice not in self.optionAnalyze.keys():
                            print("Sorry please enter your choice from the option below ")
                            break
                            self.OptionChoice()
                        if choice == 1:
                            self.getTop10(self.movieData)
                        elif choice==2:
                            self.getTop10HighBudgetMovie(self.movieData)
                        elif choice==3:
                            self.DisplayCricticAudienceRating(self.movieData)
                        elif choice==4:
                            self.OptionChoiceDist()
                        elif choice==5 :
                            self.DisplayStackedHistogram(self.movieData)
                        elif choice==6:
                            self.OptionChoiceBox()
                        elif choice==7:
                            self.OptionChoiceBar()
                    except ValueError:
                        print("Sorry! please enter a number.")
                        self.DisplayTheDetails()
                        break
                elif Choice == 'q':
                    break
        check_again=input("Do you want to check again? Y/n:\n")
        if check_again.lower() != 'n':
            self.DisplayTheDetails()
        else:
            print("\n***********************************************************************************************")
            print("Thanks for your participation, GoodBye!!!")

#########################################################################################################################
# The Main Part for Displaying Movie info to the user
#########################################################################################################################

def MainFunction():
    try:
        FirstName = input("Please Enter Your First Name:\n")
        LastName = input("Please Enter Your Last Name:\n")
        if FirstName=='' or LastName=='':
            print("Input cannot be blank...")
       
        else:
            User = ImdbMovies(firstname=FirstName, lastname=LastName)
            User.DisplayTheDetails()
    except:
        print("\n***********************************************************************************************")
        print("Please provide a valid input")
        MainFunction()
MainFunction()

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = urlopen('http://www.imdb.com/title/tt0111161/reviews?ref_=tt_ov_rt').read()
soup = BeautifulSoup(url,"html.parser")
for item in soup.find_all(class_="review-container"):
    review_title = item.find(class_="title").text
    review = item.find(class_="text").text
    try:
        rating = item.find(class_="point-scale").previous_sibling.text
    except:
        rating = ""
    print("Title: {}\nReview: {}\nRating: {}\n".format(review_title,review,rating))

# %%
# -*- coding: utf-8 -*-
"""Created on Thu Jan 24 13:50:03 2019
@author: shaz-
"""
#########################################################################################################################
# Importing Packages
#########################################################################################################################

'''
Importing The Necessary Packages
'''
import json
import re
import requests
import warnings
import numpy as np
import pandas as pd
import mysql.connector
import urllib.request
from scipy import stats
import seaborn as sns
from bs4 import BeautifulSoup
from currency_converter import CurrencyConverter
from matplotlib import pyplot as plt
import nltk   
import unicodedata
import vaderSentiment
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from nltk.sentiment.vader import SentimentIntensityAnalyzer as SIA 
from sklearn.preprocessing import scale
from sklearn.model_selection import train_test_split
from sklearn import metrics as sm
from sklearn.svm import LinearSVC
from sklearn.feature_extraction.text import TfidfVectorizer
warnings.filterwarnings('ignore')
sns.set(style="darkgrid", color_codes=True)

#########################################################################################################################
# Defining Functions
#########################################################################################################################
class ImdbMovies:
    model=''
    vectorizer=''
    mydb=''
    '''Loading constructor, so when instance is instantiate it will load our model and as well 
        as it will create a connection with the database'''
    def __init__(self,**kwargs):
        self.firstname=kwargs.get('firstname','Firstname Not Provided')
        self.lastname=kwargs.get('lastname','LastName Not Provided')
        self.mydb=self.DatabaseConnection('root','Sagar$256','imdbmovies')
        print("\nPlease wait {}, while we're running the model.....".format(self.firstname))
        self.model,self.vectorizer=self.UserReview_SentimentAnalyzer()
        print('''Done!!, you're good to go''')
        print("#########################################################################################################################")
        print("Welcome! {} {} to our movie search and data analysis program:\n".format(self.firstname.capitalize(),self.lastname.capitalize()))
        print("#########################################################################################################################")
     
    '''This is just to provide user freindly string when object is print'''             
    def __str__(self):
        return '''What's going on {} {}, enjoy your movie buddy'''.format(self.firstname.capitalize(),self.lastname.capitalize())
    
    '''Using Vader lexicon function to get the polarity'''
    def sentiment_lexicon(self,review, threshold=0.1):       
        sid = SIA()
        ss = sid.polarity_scores(review) 
        agg_score = ss['compound'] 
        if agg_score >= threshold:
            final_sentiment = 'Positive' 
        else:
            final_sentiment = 'Negative'
        return final_sentiment
    
    '''Sentiment analysis based on user review submited'''     
    def UserReview_SentimentAnalyzer(self):
        self.df=pd.read_sql("select imdbid,User_Review,Polarity from movies;",self.mydb)
        # User_Review
        self.data = self.df['User_Review']
        self.data=pd.Series.to_string(self.data)    ## converted to string from pandas.Series
        # for removing accented characters
        self.normal = unicodedata.normalize('NFKD', self.data).encode('ASCII', 'ignore')
        # sentiment_vader_lexicon:
        self.list_senti=[]
        for i in self.df['User_Review']:
            self.list_senti.append(self.sentiment_lexicon(i))
        self.list_senti
        #creating new column as sentiment which will have 0/1 values
        self.df['polarity']=self.list_senti
        # assigning
        self.features=self.df.loc[:,'User_Review']
        self.senti=self.df.loc[:,'polarity']
        # Using TFIDF vectorizer
        self.vectorizer = TfidfVectorizer(min_df= 3, stop_words="english", sublinear_tf=True, norm='l2', ngram_range=(1, 2))
        self.final_features = self.vectorizer.fit_transform(self.features).toarray()
        self.features_train,self.features_test,self.senti_train,self.senti_test=train_test_split(self.final_features,self.senti,test_size=0.2,random_state=23) 
        # SVC model to get acc & class table
        self.lsvm = LinearSVC()
        self.l = self.lsvm.fit(self.features_train,self.senti_train)
        return self.l,self.vectorizer
    
    '''Predictor function that will help to analyse user review and provide the polarity'''
    def Predict_Sentiment(self,model,vectorizer,User_Review):
    #    l=UserReview_SentimentAnalyzer()
        self.y = self.vectorizer.transform([self.User_Review]).toarray()
        self.z=model.predict(self.y)
        return self.z

    '''Displaying intial menu where user can select an option either to search the movie or analyse the movie '''
    def displayMenu(self):
        print("\nMenu:\n[S]earch Movie,[A]nalyze the data,[Q]uit:\n")
        print("---------------------------------------------------------------------------")
        Choice=''
        flag=0
        options={'s':'search','a':'analyse','q':'quit'}
        try:            
            Choice=input("Please enter your option below:\n").lower()           
            if Choice=='':
                flag=1  
                return Choice,flag
            elif Choice not in options.keys():
                flag=2
                return Choice,flag
            else:
                return Choice,flag
        except ValueError:
            print("\nInvalid input...please enter S,A,Q from choices provided:\n")
            self.displayMenu()
           
    '''Budget and Review need to be extracted from IMDB website '''
    def Extract_Budget_UserReview(self,imdbID):
        c = CurrencyConverter()
        CurrencyDict = {'$': 'USD', '£': 'GBP', '¥': 'JPY', '€': 'EUR', '₹': 'INR'}
        url = 'http://www.imdb.com/title/{}/?ref_=fn_al_nm_1a'.format(imdbID)
        data = requests.get(url)
        soup = BeautifulSoup(data.text, 'html.parser')
        Budget = 0
        userReview = ""
        
        #Extracting the user Review of the movie
        movie = soup.findAll('div', {'class': 'user-comments'})
        for res in movie:
            userReview = res.span.strong.text
            if userReview is None:
                userReview='N/A'
            
        #Extracting the Budget of the movie
        for h4 in soup.find_all('h4'):
            if "Budget:" in h4:
                Budget = h4.next_sibling
                match = re.search(r'([\D]+)([\d,]+)', Budget)
                output = (match.group(1).replace('\xa0', ''),
                          match.group(2).replace(',', ''))
                if len(output[0]) == 1:
                    Budget = round(
                        (c.convert(output[1], CurrencyDict[output[0]], 'USD')/1000000), 2)
                elif len(output[0]) == 3 and output[0] == 'XAF':
                    Budget = round((float(output[1])*0.00174637)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'FRF':
                    Budget = round((float(output[1])*0.17)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'IRR':
                    Budget = round((float(output[1])*0.0000237954)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'PKR':
                    Budget = round((float(output[1])*0.007225614)/1000000, 2)
                elif len(output[0]) == 3 and output[0] == 'NPR':
                    Budget = round((float(output[1])*87.0521)/1000000, 2)
                elif len(output[0]) == 3 and output[0] != 'FRF':
                    Budget = round(
                        c.convert(output[1], output[0], 'USD')/1000000, 2)
        return Budget,userReview
    
    '''Extracting movie details from API'''
    def getMovieData(self,Movietitle):
        try:
            url = "http://www.omdbapi.com/?t={}&apikey=5ddb11dd".format(Movietitle)
            print("Retrieving the data of \"{}\" now…".format(Movietitle))
            api_request = requests.get(url)
            source = json.loads(api_request.content)
        except requests.RequestException as e:
            print(f"ERROR: {e.reason}")
        return source
    
    '''Establishing the database connection'''
    def DatabaseConnection(self,user, passwd, database):
        mydb=''
        try:
            mydb = mysql.connector.connect(host='localhost',
                                           user=user,
                                           passwd=passwd,
                                           db=database)
        except:
            print("""The login credentials you entered are not valid for
                the database you indicated.  Please check your login details and try
                again.""")        
        return mydb
    
    '''This function will sepearte each word from genre and stack it in long format'''
    def explode(self,df, lst_cols, fill_value=''):
        # make sure `lst_cols` is a list
        if lst_cols and not isinstance(lst_cols, list):
            lst_cols = [lst_cols]
        # all columns except `lst_cols`
        idx_cols = df.columns.difference(lst_cols)
    
        # calculate lengths of lists
        lens = df[lst_cols[0]].str.len()
    
        if (lens > 0).all():
            # ALL lists in cells aren't empty
            return pd.DataFrame({
                col: np.repeat(df[col].values, lens)
                for col in idx_cols
            }).assign(**{col: np.concatenate(df[col].values) for col in lst_cols}) \
              .loc[:, df.columns]
        else:
            # at least one list in cells is empty
            return pd.DataFrame({
                col: np.repeat(df[col].values, lens)
                for col in idx_cols
            }).assign(**{col: np.concatenate(df[col].values) for col in lst_cols}) \
              .append(df.loc[lens == 0, idx_cols]).fillna(fill_value) \
              .loc[:, df.columns]
    
    '''This Function will put the data extracted from API and from webscraping into movie database '''    
    def DataIntoDatabase(self,MovieData, mydb, mycursor):
        self.budget,self.User_Review = self.Extract_Budget_UserReview(MovieData['imdbID'])
        self.pred=self.Predict_Sentiment(self.model,self.vectorizer,self.User_Review)
        self.polarity=''.join(self.pred)
        if MovieData['Metascore'] == 'N/A':
           metascore = 0
        else:
           metascore = (float((MovieData['Metascore']))/10)
                    
        if MovieData['imdbRating']=='N/A':
           imdb_rating=0
        else:
           imdb_rating = float(MovieData['imdbRating'])
    
        if MovieData['Released']=='N/A':
           release_year=0
        else:
           release_year=int(MovieData['Released'].split(' ')[2])
            
        if MovieData['Poster']=="N/A":
           image_url='Image Not Available'
        else:
           image_url=MovieData['Poster']
            
        sql = """INSERT INTO movies(IMDBID, Title, Genre, Year, URL, Audience_Rating, Critic_Rating, Budget_In_Millions, User_Review,Polarity) 
                    VALUES (%s, %s,%s, %s,%s,%s,%s,%s,%s,%s)
                    ON DUPLICATE KEY UPDATE 
                    Audience_Rating=values(Audience_Rating),
                    Critic_Rating=values(Critic_Rating),
                    Budget_In_Millions=values(Budget_In_Millions),
                    User_Review=values(User_Review),
                    Polarity=values(Polarity);"""
    
        val=[(MovieData['imdbID'],MovieData['Title'],
            MovieData['Genre'],release_year,image_url,
            imdb_rating,metascore,self.budget,self.User_Review,self.polarity)] 
        mycursor.executemany(sql, val)
        mydb.commit()
 
    
    '''This function will fetch the data from database from the title provided by the user'''   
    def getDataFromDatabase(self,UserInputTitle):       
        mydb=self.mydb
        self.mycursor=mydb.cursor()  
        self.mycursor.execute("""select title,genre,year,audience_rating,critic_rating,polarity 
                         from movies where title like %s limit 1""",("%" + self.UserInputTitle + "%",))
        self.myresult = self.mycursor.fetchall()
        return self.myresult
    
    '''
    This is use to display info about the movie title provided by the user, 
    at the same time if the movie title doesn't exist the it will make an entry into the database 
    and then it will fetch the data from database to display info. 
    '''    
    def DisplayMovieInfo(self,UserInputTitle):   
        mydb=self.mydb
        mycursor=mydb.cursor()
        try:
            myresult=self.getDataFromDatabase(self.UserInputTitle)
            if not myresult:
                MovieData=self.getMovieData(self.UserInputTitle)
                if MovieData['Response']=='False':
                  print("Sorry!!! The Movie Doesn't Exist.....:(")
                else:
                    self.DataIntoDatabase(MovieData,mydb,mycursor)           
                    myresult=self.getDataFromDatabase(self.UserInputTitle)
                    if myresult[0][5]=='Positive':
                        res="Good Choice! & you can enjoy this with your buddy. :)"
                    else:
                        res="Well, you've decide so enjoy this with your popcorn. :)."
                print('*********************************************************')
                print("Title: {}".format(myresult[0][0]))
                print("Genre: {}".format(myresult[0][1]))
                print("Year: {}".format(myresult[0][2]))
                print("Audience Rating: {}".format(myresult[0][3]))
                print("Critic Rating: {}".format(myresult[0][4]))
                print("What's My Sugesstion: {}".format(res))
                print('*********************************************************')
            else:
                if myresult[0][5]=='Positive':
                    res="Your can enjoy this with your buddy!"
                else:
                    res="Well you've decide so enjoy with your popcorn."
                print('*********************************************************')
                print("Title: {}".format(myresult[0][0]))
                print("Genre: {}".format(myresult[0][1]))
                print("Year: {}".format(myresult[0][2]))
                print("Audience Rating: {}".format(myresult[0][3]))
                print("Critic Rating: {}".format(myresult[0][4]))
                print("What's My Sugesstion: {}".format(res))
                print('*********************************************************')
        except:
            print('''Sorry its doesnt exist...please try once again''')

    
    '''This Function will fetch the data by year'''
    def getDataByYear(self,FirstRange,SecondRange):       
        self.movieData=pd.read_sql("""select title,genre,year,audience_rating,critic_rating,budget_in_millions 
                                    from movies 
                                    where url!='N/A' and 
                                    genre!='N/A'and 
                                    year!=0 and 
                                    Audience_rating!=0 and 
                                    critic_rating!=0 and 
                                    budget_in_millions!=0 and 
                                    user_review <> ''and polarity <> '' and Year BETWEEN {} and {};""".format(FirstRange,SecondRange),self.mydb)
        return self.movieData

    '''Getting an input title from the user'''    
    def getChoiceMovie(self):    
        try:
            self.UserInputTitle=input("Please enter the title of the movie:\n")
            if self.UserInputTitle=='':
                print("No Input Provided.")
            else:
                self.DisplayMovieInfo(self.UserInputTitle)
        except ValueError:
            print("\nSome error occured.....please check the input provided")
    
    '''This fucntion will fetch the data from the database & process it while formatting the data in long format'''    
    def DataAnalysis(self):
        self.movieData=''
        self.year=pd.read_sql('''select max(year) as Max_Year, min(year) as Min_Year 
                             from movies where url!='N/A' and 
                             genre!='N/A'and year!=0 and 
                             Audience_rating!=0 and 
                             critic_rating!=0 and 
                             budget_in_millions!=0 and 
                             user_review <> '' and 
                             Polarity <>'' ''',self.mydb)
        
        print('***********************************************************************************************')
        print("Data is avialable from {} to {}.\nEnter the range so as to bring you the analysis".format(self.year.Min_Year[0],self.year.Max_Year[0]))
        print('***********************************************************************************************')
        try:
            self.FirstRange=input("Please Enter The Range 1:\n")
            self.SecondRange=input("Please Enter The Range 2:\n")
            if self.FirstRange=='' or self.SecondRange=='':
                print("No input was provided.\n")
                self.DataAnalysis()
            elif self.FirstRange > self.SecondRange:
                print('\nProvided range is invalid...since the first range cannot be greater than the second.\n')
                self.DataAnalysis()
            elif len(self.FirstRange)!=4 or len(self.SecondRange)!=4:
                print("Provided range is invalid...\n")
                self.DataAnalysis()
            else:
                self.movieData=self.getDataByYear(int(self.FirstRange),int(self.SecondRange))
                self.movieData.genre = self.movieData.genre.str.split(',')
                self.movieData = self.explode(self.movieData,['genre']) 
                self.movieData.genre=self.movieData.genre.str.strip(' ')
                self.movieData.genre=self.movieData.genre.astype('category')
                self.movieData.audience_rating=self.movieData.audience_rating*10
                self.movieData.critic_rating=self.movieData.critic_rating*10
    
        except ValueError:
            print("Please provide correct input...since the entered value is not a number.\n")
            self.DataAnalysis()
        return self.movieData
    
    def OptionChoice(self):
        print("""Please Choose option below:
        1. Display Top 10 Rated Movies
        2. Display Top 10 High Budget Movies
        3. Display Critic Vs Audience Rating
        4. Distribution of Critic or Audience Rating
        5. Display Stack Distribution of Budget
        6. Display Boxplot
        7. Display Barplot\n
            """)
    
    def OptionChoiceDist(self):
        self.optionDist={1:'Critic Rating Distribution',2:'Audience Rating Distribution'}
        print("""Please Enter:\n[1] Critic Rating Distribution\n[2] Audience Rating Distribution\n""")
        try:
            self.Dist=int(input(">"))
            if self.Dist not in self.optionDist.keys():
                print("Sorry please enter your choice from the option below\n")
                self.OptionChoiceDist()
            elif self.Dist==1:
                self.DisplayHistogram(self.movieData,'critic rating')
            elif self.Dist==2:
                self.DisplayHistogram(self.movieData,'audience rating')                              
        except ValueError:
            print("Invalid input provided.")
            self.OptionChoiceDist()
            
    def OptionChoiceBox(self):
        self.optionbox={1:'Critic Rating Boxplot',2:'Audience Rating Boxplot'}
        print("""Please Enter:\n[1] Display boxplot for critic rating by genre\n[2] Display boxplot for audience rating by genre\n""")
        try:
            self.box=int(input(">"))
            if self.box not in self.optionbox.keys():
                print("Sorry please enter your choice from the option below\n")
                self.OptionChoiceBox()
            elif self.box==1:
                self.DisplayBoxplot(self.movieData,'genre','critic rating')
            elif self.box==2:
                self.DisplayBoxplot(self.movieData,'genre','audience rating')
        except ValueError:
            print("Invalid input provided.")
            self.OptionChoiceBox()
    
    def OptionChoiceBar(self):
        self.optionbar={1:'Genre bar plot',2:'Year bar plot'}
        print("""Please Enter:\n[1] Display barplot to display Data by Genre\n[2] Display barplot to display Data by year:\n""")
        try:
            self.bar=int(input(">"))
            if self.bar not in self.optionbar.keys():
                print("Sorry please enter your choice from the option below\n")
                self.OptionChoiceBar()
            elif self.bar==1:
                self.catPlot(self.movieData,'genre')
            elif self.bar==2:
                self.catPlot(self.movieData,'year')
        except ValueError:
            print("Invalid input provided.")
            self.OptionChoiceBar()
       
    def DisplayCricticAudienceRating(self,movieData):
        #Joint Plot Critic Rating Vs Audience Rating
        sns.set(style='whitegrid')
        sns.jointplot(data=self.movieData,x='critic_rating',y='audience_rating')
        j = sns.JointGrid(data=self.movieData,x='critic_rating',y='audience_rating')
        j = j.plot_joint(plt.scatter,color="g", s=40, edgecolor="black")
        j = j.plot_marginals(sns.distplot, kde=False,)
        j = j.annotate(stats.pearsonr,loc="upper left")
        j.set_axis_labels('Critic Ratings','Audience Rating')
        plt.show()
    
    # Histogram
    def DisplayHistogram(self,movieData,column):
        column=column.title()
        LabelDictCol = {'Critic Rating':'critic_rating','Audience Rating':'audience_rating','Budget In Millions':'budget_in_millions'}        
        sns.set(style = 'whitegrid')
        fig,ax=plt.subplots()
        fig.set_size_inches(11.7,8.27)
        plt.hist(movieData[LabelDictCol[column]],bins=15,color='black')
        plt.title("{} Distribution".format(column),fontsize=20)
        plt.ylabel("Frequency",fontsize=15)
        plt.xlabel("{} (%)".format(column),fontsize=15)
        plt.show()
    
    # Stack distribution
    def DisplayStackedHistogram(self,movie):
        list1=[]
        GenreLabels=[]
        for gen in movie.genre.cat.categories:
            list1.append(movie[movie.genre==gen].budget_in_millions)
            GenreLabels.append(gen)
            sns.set(style='whitegrid')        
        fig,ax=plt.subplots()
        fig.set_size_inches(11.7,8.27)
        plt.hist(list1,bins=30,stacked=True,rwidth=1,label=GenreLabels)
        plt.title("Movie Budget Distribution",fontsize=20)
        plt.ylabel("Number of Movies",fontsize=15)
        plt.xlabel("Budget$$$",fontsize=15)
        plt.legend(frameon=True,fancybox=True,prop={'size':10},framealpha=1)
        plt.show()
    
    
    # how critic rating is dtributted accross different genre
    def DisplayBoxplot(self,data,column1,column2): 
        column1=column1.title()
        column2=column2.title()
        LabelDictCol = {'Critic Rating':'critic_rating','Audience Rating':'audience_rating','Budget In Millions':'budget_in_millions','Genre':'genre','Year':'year'}        
        fig,ax=plt.subplots() 
        fig.set_size_inches(11.7,8.27)
        sns.boxplot(data=data,x=LabelDictCol[column1],y=LabelDictCol[column2],palette='vlag',whis="range")
        ax.yaxis.grid(True)
        ax.xaxis.grid(True)
        plt.title('{} Vs {} Boxplot'.format(column1,column2),fontsize=20)
        plt.xlabel('{}'.format(column1),fontsize=15)
        plt.ylabel('{}'.format(column2),fontsize=15)
        plt.xticks(rotation=30)
        sns.despine(trim=True, left=True)
        plt.show()    

    '''Function is use to display barplot for number of movie by genre or year'''
    def catPlot(self,data,column):
        column=column.title()
        LabelDictCol = {'Critic Rating':'critic_rating','Audience Rating':'audience_rating','Budget In Millions':'budget_in_millions','Genre':'genre','Year':'year'}      
        sns.catplot(y=LabelDictCol[column], kind="count", palette="ch:.25", data=data)
        plt.title('Barplot For {}'.format(column.capitalize()),fontsize=20)
        plt.ylabel('{}'.format(column.capitalize()),fontsize=15)
        plt.xlabel('')
        plt.show()
    
    '''Display top 10 movie w.r.t genre or year'''
    def getTop10(self,data):
        p=sns.factorplot(aspect=1.5,y='title',x='audience_rating',data=data.sort_values(['audience_rating','critic_rating'],ascending=False).drop(['genre'],axis=1).drop_duplicates().head(10),palette="ch:.25",kind='bar')
        p.set(xlim=(10,100))
        sns.set_style("ticks",{"xtick.major.size":8,"ytick.major.size":8})
        plt.title('Top 10 Rated Movies',fontsize=20)
        plt.ylabel('Title',fontsize=15)
        plt.xlabel('Audience Rating',fontsize=15)
        sns.despine(trim=True,left=True)
        plt.show()
    
    '''Function will display top 10 movie w.r.t budget'''
    def getTop10HighBudgetMovie(self,data):
        sns.factorplot(aspect=1.5,y='title',x='budget_in_millions',data=data.sort_values(['budget_in_millions'],ascending=False).drop(['genre'],axis=1).drop_duplicates().head(10),palette="ch:.25",kind='bar')
        sns.set_style("ticks",{"xtick.major.size":8,"ytick.major.size":8})
        plt.title('Top 10 High Budget Movies',fontsize=20)
        plt.ylabel('Title',fontsize=15)
        plt.xlabel('Budget In Millions',fontsize=15)
        sns.despine(trim=True,left=True)
        plt.show()            
    
    
    '''This is function will be call after the object is created and its link with mulitple functions from above'''    
    def DisplayTheDetails(self):
        self.options={'s':'search','a':'analyse','q':'quit'}
        while True:            
            Choice,flag = self.displayMenu()
            if flag==1 and Choice=='':
                print("Please select the option from the menu:\n")
                break
                self.displayMenu()
            elif flag==2 and Choice not in self.options.keys():
                print("Please select the option from the menu:\n")
                break
                self.displayMenu()
            elif flag==0 and Choice in self.options.keys():
                if Choice == 's':
                    self.getChoiceMovie()
                    break
                elif Choice == 'a':
                    self.optionAnalyze={1:'Display Top 10 Rated Movies',2:'Display Top 10 High Budget Movies',3: 'Display Critic Vs Audience',
                     4:'Distribution of Critic Vs Audience',5:'Display Stack Distribution of Budget',6:'Display Boxplot',7:'Display Barplot',
                     8:'Display Dashboard'}  
                    self.movieData=self.DataAnalysis()
                    try:
                        self.OptionChoice()
                        choice=int(input("Please enter the option below:\n"))
                        if choice not in self.optionAnalyze.keys():
                            print("Sorry please enter your choice from the option below ")
                            break
                            self.OptionChoice()
                        if choice == 1:
                            self.getTop10(self.movieData)
                        elif choice==2:
                            self.getTop10HighBudgetMovie(self.movieData)
                        elif choice==3:
                            self.DisplayCricticAudienceRating(self.movieData)
                        elif choice==4:
                            self.OptionChoiceDist()
                        elif choice==5 :
                            self.DisplayStackedHistogram(self.movieData)
                        elif choice==6:
                            self.OptionChoiceBox()
                        elif choice==7:
                            self.OptionChoiceBar()
                    except ValueError:
                        print("Sorry! please enter a number.")
                        self.DisplayTheDetails()
                        break
                elif Choice == 'q':
                    break
        check_again=input("Do you want to check again? Y/n:\n")
        if check_again.lower() != 'n':
            self.DisplayTheDetails()
        else:
            print("\n***********************************************************************************************")
            print("Thanks for your participation, GoodBye!!!")

#########################################################################################################################
# The Main Part for Displaying Movie info to the user
#########################################################################################################################

def MainFunction():
    try:
        FirstName = input("Please Enter Your First Name:\n")
        LastName = input("Please Enter Your Last Name:\n")
        if FirstName=='' or LastName=='':
            print("Input cannot be blank...")
       
        else:
            User = ImdbMovies(firstname=FirstName, lastname=LastName)
            User.DisplayTheDetails()
    except:
        print("\n***********************************************************************************************")
        print("Please provide a valid input")
        MainFunction()
MainFunction()
